# %% [markdown]
# # Llama Pack - Neo4j 查询引擎
# 本 Llama Pack 创建了一个 Neo4j 知识图谱查询引擎，并执行其 `query` 函数。此包提供了为 Neo4j 知识图谱创建多种类型的查询引擎的选项，包括：
#
# * 知识图谱基于向量的实体检索（如果没有提供查询引擎类型选项，则为默认选项）
# * 知识图谱基于关键词的实体检索
# * 知识图谱混合实体检索
# * 原始向量索引检索
# * 自定义组合查询引擎（向量相似性 + 知识图谱实体检索）
# * KnowledgeGraphQueryEngine
# * KnowledgeGraphRAGRetriever
#
# 对于这个笔记本，我们将加载一个关于古食饮食的维基百科页面到 Neo4j 知识图谱中，并执行查询。

# %% [markdown]
# ## 安装了必要的库
#
# - `llama_index`：将大语言模型和外部数据连接在一起的工具
# - `neo4j`：用于存储采集的数据，支持实体和属性等关系查询
# - `llama_hub`：一个社区驱动的预打包模块中心，可以使用它来启动 LLM 应用程序

# %%
# %pip install llama_index llama_hub neo4j
# Out:
# Requirement already satisfied: llama_index in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (0.9.21)
# Requirement already satisfied: llama_hub in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (0.0.64)
# Requirement already satisfied: neo4j in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (5.15.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama_index) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (4.12.2)
# Requirement already satisfied: dataclasses-json in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (2023.12.2)
# Requirement already satisfied: httpx in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (0.26.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (1.5.8)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (3.8.1)
# Requirement already satisfied: numpy in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (1.26.2)
# Requirement already satisfied: openai>=1.1.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (1.6.1)
# Requirement already satisfied: pandas in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (2.1.4)
# Requirement already satisfied: requests>=2.31.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_index) (0.9.0)
# Requirement already satisfied: html2text in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_hub) (2020.1.16)
# Requirement already satisfied: psutil in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_hub) (5.9.7)
# Requirement already satisfied: pyaml<24.0.0,>=23.9.7 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_hub) (23.12.0)
# Requirement already satisfied: retrying in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from llama_hub) (1.3.4)
# Requirement already satisfied: pytz in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from neo4j) (2023.3.post1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->llama_index) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from deprecated>=1.2.9.3->llama_index) (1.16.0)
# Requirement already satisfied: click in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama_index) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama_index) (4.66.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from openai>=1.1.0->llama_index) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from openai>=1.1.0->llama_index) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from openai>=1.1.0->llama_index) (2.5.3)
# Requirement already satisfied: sniffio in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from openai>=1.1.0->llama_index) (1.3.0)
# Requirement already satisfied: certifi in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from httpx->llama_index) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from httpx->llama_index) (1.0.2)
# Requirement already satisfied: idna in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from httpx->llama_index) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama_index) (0.14.0)
# Requirement already satisfied: PyYAML in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from pyaml<24.0.0,>=23.9.7->llama_hub) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from requests>=2.31.0->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from requests>=2.31.0->llama_index) (2.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama_index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from dataclasses-json->llama_index) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from pandas->llama_index) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from pandas->llama_index) (2023.3)
# Requirement already satisfied: six>=1.7.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from retrying->llama_hub) (1.16.0)
# Requirement already satisfied: packaging>=17.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama_index) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama_index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama_index) (2.14.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 调整输出日志配置

# %%
import os, logging, sys

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

# %% [markdown]
# ## 加载数据
#
# 加载维基百科中关于古法饮食的页面。

# %%
from llama_index import download_loader

WikipediaReader = download_loader("WikipediaReader")
loader = WikipediaReader()
documents = loader.load_data(pages=['Paleolithic diet'], auto_suggest=False)
print(f'Loaded {len(documents)} documents')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llamahub.ai:443
# DEBUG:urllib3.connectionpool:https://llamahub.ai:443 "POST /api/analytics/downloads HTTP/1.1" 200 63
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.0.1:7890
# DEBUG:urllib3.connectionpool:http://127.0.0.1:7890 "GET http://en.wikipedia.org/w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Paleolithic+diet&format=json&action=query HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): en.wikipedia.org:443
# DEBUG:urllib3.connectionpool:https://en.wikipedia.org:443 "GET /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Paleolithic+diet&format=json&action=query HTTP/1.1" 200 477
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.0.1:7890
# DEBUG:urllib3.connectionpool:http://127.0.0.1:7890 "GET http://en.wikipedia.org/w/api.php?prop=extracts%7Crevisions&explaintext=&rvprop=ids&titles=Paleolithic+diet&format=json&action=query HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): en.wikipedia.org:443
# DEBUG:urllib3.connectionpool:https://en.wikipedia.org:443 "GET /w/api.php?prop=extracts%7Crevisions&explaintext=&rvprop=ids&titles=Paleolithic+diet&format=json&action=query HTTP/1.1" 200 None
# Loaded 1 documents

# %% [markdown]
# ## 下载并初始化软件包

# %% [markdown]
# ### 使用 OpenAI 相关配置

# %%
# from llama_index.llama_pack import download_llama_pack

# os.environ['OPENAI_API_KEY'] = "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"

# # download and install dependencies
# Neo4jQueryEnginePack = download_llama_pack(
#   "Neo4jQueryEnginePack", "./neo4j_pack"
# )

# %% [markdown]
# ### 使用 AuzreOpenAI 相关配置（当前项目的默认使用配置）

# %%
from neo4j_pack.base import Neo4jQueryEnginePack
# neo4j_pack.base 配置对应的 Auzre 账号

# %% [markdown]
# ## Neo4j 安装与配置

# %% [markdown]
# #### 安装 neo4j 服务
# ```shell
# docker run -d -p 7474:7474 -p 7687:7687 --name neo4j-apoc -e NEO4J_apoc_export_file_enabled=true -e NEO4J_apoc_import_file_enabled=true -e NEO4J_apoc_import_file_use__neo4j__config=true -e NEO4J_AUTH=neo4j/pleaseletmein -e NEO4J_PLUGINS=\[\"apoc\"\] neo4j:latest
# ```
# - username：neo4j
# - password：pleaseletmein
# - url：bolt://127.0.0.1:7687
# - database：username：neo4j

# %% [markdown]
# ### 配置 Neo4j 信息
# Neo4j 的证书存储在项目根目录下的 `credentials.json` 中，加载 json 并提取证书详细信息。
# 请开 [credentials.json](./credentials.json) ，配置安装的 Neo4j 服务时的指定的账号信息

# %%
import json

# get Neo4j credentials (assume it's stored in credentials.json)
with open('credentials.json') as f:
  neo4j_connection_params = json.load(f)
  username = neo4j_connection_params['username']
  password = neo4j_connection_params['password']
  url = neo4j_connection_params['url']
  database = neo4j_connection_params['database']

# %% [markdown]
# 以下是 `Neo4jQueryEnginePack`的构造方式。你可以从 `Neo4jQueryEngineType` 传入 `query_engine_type` 来构建 `Neo4jQueryEnginePack`。下面的代码片段展示了一个知识图谱（KG）关键词查询引擎。如果没有定义 `query_engine_type`，它默认为基于KG向量的实体检索。
#
# `Neo4jQueryEngineType` 是一个枚举类型，包含多种查询引擎类型，如下所示。你可以传入其中任何一个查询引擎类型来构建 `Neo4jQueryEnginePack`。
#
#
# ```
# class Neo4jQueryEngineType(str, Enum):
#     """Neo4j query engine type"""
#
#     KG_KEYWORD = "keyword"
#     KG_HYBRID = "hybrid"
#     RAW_VECTOR = "vector"
#     RAW_VECTOR_KG_COMBO = "vector_kg"
#     KG_QE = "KnowledgeGraphQueryEngine"
#     KG_RAG_RETRIEVER = "KnowledgeGraphRAGRetriever"
# ```

# %%
from llama_hub.llama_packs.neo4j_query_engine.base import Neo4jQueryEngineType


# create the pack
neo4j_pack = Neo4jQueryEnginePack(
  username = username,
  password = password,
  url = url,
  database = database,
  docs = documents,
  query_engine_type = Neo4jQueryEngineType.KG_KEYWORD,
)
# Out:
# DEBUG:neo4j:[#0000]  _: <POOL> created, direct address IPv4Address(('127.0.0.1', 7687))
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='READ', database=None
# DEBUG:neo4j:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j:[#0000]  _: <RESOLVE> in: 127.0.0.1:7687
# DEBUG:neo4j:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j:[#D907]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j:[#D907]  C: <HANDSHAKE> 0x00040405 0x00020404 0x00000104 0x00000003
# DEBUG:neo4j:[#D907]  S: <HANDSHAKE> 0x00000405
# DEBUG:neo4j:[#D907]  C: HELLO {'user_agent': 'neo4j-python/5.15.0 Python/3.11.6-final-0 (darwin)', 'bolt_agent': {'product': 'neo4j-python/5.15.0', 'platform': 'Darwin 23.2.0; arm64', 'language': 'Python/3.11.6-final-0', 'language_details': 'CPython; 3.11.6-final-0 (main, Oct  3 2023 10:37:07) [Clang 15.0.7 ]'}}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j:[#D907]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j:[#D907]  S: SUCCESS {'server': 'Neo4j/5.15.0', 'connection_id': 'bolt-77', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j:[#D907]  S: SUCCESS {}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "node"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {labels: nodeLabels, properties: properties} AS output\n\n' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> client state: READY > STREAMING
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': ['output']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'r', 't_last': 21, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "relationship"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {type: nodeLabels, properties: properties} AS output\n' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 0, 'fields': ['output']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'r', 't_last': 15, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE type = "RELATIONSHIP" AND elementType = "node"\nUNWIND other AS other_node\nRETURN {start: label, type: property, end: toString(other_node)} AS output\n' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': ['output']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'r', 't_last': 4, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                ' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 0, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 's', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: The Paleolithic diet, Paleo diet, caveman diet,...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Foodstuffs ==
# The basis of the diet is a re-...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Health effects ==
# The paleolithic diet is co...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Genetics ==
# The stated rationale for the pal...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == See also ==
#
#
# == Citations ==
#
#
# == Reference...
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The Paleolithic diet, Paleo diet, caveman diet, or stone-age diet is a modern fad diet consisting of foods thought by its proponents to mirror those eaten by humans during the Paleolithic era.The diet avoids food processing and typically includes vegetables, fruits, nuts, roots, and meat and excludes dairy products, grains, sugar, legumes, processed oils, salt, alcohol, and coffee. Historians can trace the ideas behind the diet to "primitive" diets advocated in 19th century. In the 1970s, Walter L. Voegtlin popularized a meat-centric "Stone Age" diet; in the 21st century the best-selling books of Loren Cordain popularized the Paleo diet. As of 2019 the paleo-diet industry was worth approximately US$500 million.In the 21st century, the sequencing of the human genome and DNA analysis of the remains of early humans have found evidence that humans evolved rapidly in response to changing diet. This evidence undermines a core premise of the paleolithic diet – that human digestion has remained essentially unchanged over time. Anthropological science has found that human diets in paleolithic times were more varied and less meat-centric than had previously been assumed.\nAdvocates promote the paleolithic diet as a way of improving health. There is some evidence that following it may lead to improvements in body composition and metabolism compared with the typical Western diet or compared with diets recommended by some European nutritional guidelines. On the other hand, following the diet can lead to nutritional deficiencies such as an inadequate calcium intake, and side effects can include weakness, diarrhea, and headaches.\n\n\n== History and terminology ==\nAdrienne Rose Johnson writes that the idea that the primitive diet was superior to current dietary habits dates back to the 1890s with such writers as Emmet Densmore and John Harvey Kellogg. Densmore proclaimed that "bread is the staff of death", while Kellogg supported a diet of starchy and grain-based foods in accord with "the ways and likings of our primitive ancestors". Arnold DeVries advocated an early version of the Paleolithic diet in his 1952 book, Primitive Man and His Food. In 1958, Richard Mackarness authored Eat Fat and Grow Slim, which proposed a low-carbohydrate "Stone Age" diet.In his 1975 book The Stone Age Diet, gastroenterologist Walter L. Voegtlin advocated a meat-based diet, with low proportions of vegetables and starchy foods, based on his declaration that humans were "exclusively flesh-eaters" until 10,000 years ago.In 1985 Stanley Boyd Eaton and Melvin Konner published a controversial article in the New England Journal of Medicine proposing that modern humans were biologically very similar to their primitive ancestors and so "genetically programmed" to consume pre-agricultural foods. Eaton and Konner proposed a "discordance hypothesis" by which the mismatch between modern diet and human biology gave rise to lifestyle diseases, such as obesity and diabetes.The diet started to become popular in the 21st century, where it attracted a largely internet-based following using web sites, forums and social media.This diet\'s ideas were further popularized by Loren Cordain, a health scientist with a Ph.D. in physical education, who trademarked the words "The Paleo Diet" and who wrote a 2002 book of that title.In 2012 the paleolithic diet was de ...
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7890 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14d08e310>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'Connection established', [])
# DEBUG:httpcore.proxy:start_tls.started ssl_context=<ssl.SSLContext object at 0x14c78fad0> server_hostname='firstaiproject.openai.azure.com' timeout=60.0
# DEBUG:httpcore.proxy:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14d077f90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'1375'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'53b6fd09-dc8d-455e-8528-e9f9dbeeb126'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'119'), (b'x-ratelimit-remaining-tokens', b'119984'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'1e890a84-6b9c-4fbe-a213-722abeef9fa3'), (b'x-ms-client-request-id', b'53b6fd09-dc8d-455e-8528-e9f9dbeeb126'), (b'azureml-model-session', b'turbo-0613-bc549a28'), (b'Date', b'Thu, 28 Dec 2023 09:03:51 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.indices.knowledge_graph.base:> Extracted triplets: [('Paleolithic diet', 'is', 'fad diet'), ('Walter L. Voegtlin', 'popularized', 'meat-centric "Stone Age" diet'), ('Loren Cordain', 'popularized', 'Paleo diet'), ('paleo-diet industry', 'worth', 'approximately US$500 million'), ('paleolithic diet', 'promotes', 'improving health'), ('paleolithic diet', 'can lead to', 'nutritional deficiencies')]
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'fad diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 5, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`POPULARIZED`]->(n2)\n        ' {'subj': 'Walter L. Voegtlin', 'obj': 'meat-centric "Stone Age" diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`POPULARIZED`]->(n2)\n        ' {'subj': 'Loren Cordain', 'obj': 'Paleo diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 3, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`WORTH`]->(n2)\n        ' {'subj': 'paleo-diet industry', 'obj': 'approximately US$500 million'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PROMOTES`]->(n2)\n        ' {'subj': 'paleolithic diet', 'obj': 'improving health'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`CAN_LEAD_TO`]->(n2)\n        ' {'subj': 'paleolithic diet', 'obj': 'nutritional deficiencies'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x14d0bf2e0>, 'json_data': {'input': ["('Paleolithic diet', 'is', 'fad diet')", '(\'Walter L. Voegtlin\', \'popularized\', \'meat-centric "Stone Age" diet\')', "('Loren Cordain', 'popularized', 'Paleo diet')", "('paleo-diet industry', 'worth', 'approximately US$500 million')", "('paleolithic diet', 'promotes', 'improving health')", "('paleolithic diet', 'can lead to', 'nutritional deficiencies')"], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7890 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14d03a3d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'Connection established', [])
# DEBUG:httpcore.proxy:start_tls.started ssl_context=<ssl.SSLContext object at 0x14d1f4050> server_hostname='firstaiproject.openai.azure.com' timeout=5.0
# DEBUG:httpcore.proxy:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14d0b3350>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Length', b'49769'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'x-content-type-options', b'nosniff'), (b'x-ratelimit-remaining-requests', b'119'), (b'apim-request-id', b'c94d0b8b-ac10-4c07-82b1-fefc026b02bf'), (b'x-ratelimit-remaining-tokens', b'119915'), (b'x-request-id', b'f6f35c01-9cc1-474d-820d-281260d10faf'), (b'x-ms-client-request-id', b'c94d0b8b-ac10-4c07-82b1-fefc026b02bf'), (b'x-ms-region', b'East US'), (b'azureml-model-session', b'wd3a5f6e70955-5'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Date', b'Thu, 28 Dec 2023 09:03:52 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: == Foodstuffs ==\nThe basis of the diet is a re-imagining of what Paleolithic people ate, and different proponents recommend different diet compositions. Eaton and Konner, for example, wrote a 1988 book The Paleolithic Prescription with Marjorie Shostak, and it described a diet that is 65% plant-based. This is not typical of more recently devised paleo diets; Loren Cordain\'s – probably the most popular – instead emphasizes animal products and avoidance of processed food. Diet advocates concede the modern paleolithic diet cannot be a faithful recreation of what paleolithic people ate, and instead aim to "translate" that into a modern context, avoiding such likely historical practices as cannibalism.Foodstuffs that have been described as permissible include:\n\n"vegetables, fruits, nuts, roots, meat, and organ meats";\n"vegetables (including root vegetables), fruit (including fruit oils, e.g., olive oil, coconut oil, and palm oil), nuts, fish, meat, and eggs, and it excluded dairy, grain-based foods, legumes, extra sugar, and nutritional products of industry (including refined fats and refined carbohydrates)"; and\n"avoids processed foods, and emphasizes eating vegetables, fruits, nuts and seeds, eggs, and lean meats".The diet forbids the consumption of all dairy products. This is because milking did not exist until animals were domesticated after the Paleolithic era.\n\n\n=== Ancestral diet ===\n\nAdopting the Paleolithic diet assumes that modern humans can reproduce the hunter-gatherer diet. Molecular biologist Marion Nestle argues that "knowledge of the relative proportions of animal and plant foods in the diets of early humans is circumstantial, incomplete, and debatable and that there are insufficient data to identify the composition of a genetically determined optimal diet. The evidence related to Paleolithic diets is best interpreted as supporting the idea that diets based largely on plant foods promote health and longevity, at least under conditions of food abundance and physical activity." Ideas about Paleolithic diet and nutrition are at best hypothetical.The data for Cordain\'s book only came from six contemporary hunter-gatherer groups, mainly living in marginal habitats. One of the studies was on the !Kung, whose diet was recorded for a single month, and one was on the Inuit. Due to these limitations, the book has been criticized as painting an incomplete picture of the diets of Paleolithic humans. It has been noted that the rationale for the diet does not adequately account for the fact that, due to the pressures of artificial selection, most modern domesticated plants and animals differ drastically from their Paleolithic ancestors; likewise, their nutritional profiles are very different from their ancient counterparts. For example, wild almonds produce potentially fatal levels of cyanide, but this trait has been bred out of domesticated varieties using artificial selection. Many vegetables, such as broccoli, did not exist in the Paleolithic period; broccoli, cabbage, cauliflower, and kale are modern cultivars of the ancient species Brassica oleracea.Trying to devise an ideal diet by studying contemporary hunter-gatherers is difficult because of the great disparities that exist; for example, the animal-derived calorie percentage ranges from 25% for the Gwi people of southern Africa to 99% f ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'1216'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'1c567aa7-820a-4e0f-8cc0-eea7e41e1cc0'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'119'), (b'x-ratelimit-remaining-tokens', b'119968'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'f2a30e49-95e1-4069-ab19-d27172d982fc'), (b'x-ms-client-request-id', b'1c567aa7-820a-4e0f-8cc0-eea7e41e1cc0'), (b'azureml-model-session', b'turbo-0613-65c7dc11'), (b'Date', b'Thu, 28 Dec 2023 09:03:54 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.indices.knowledge_graph.base:> Extracted triplets: [('Foodstuffs', 'is', 'basis of diet'), ('diet', 'is', 're-imagining of what Paleolithic people ate'), ('proponents', 'recommend', 'different diet compositions'), ('Eaton and Konner', 'wrote', 'The Paleolithic Prescription'), ('book', 'described', 'diet'), ('diet', 'is', '65% plant-based'), ('paleo diets', 'emphasizes', 'animal products'), ('paleo diets', 'avoidance of', 'processed food'), ('diet advocates', 'aim to', '"translate" into modern context'), ('diet', 'forbids', 'consumption of all dairy products')]
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Foodstuffs', 'obj': 'basis of diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'diet', 'obj': 're-imagining of what Paleolithic people ate'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 16, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`RECOMMEND`]->(n2)\n        ' {'subj': 'proponents', 'obj': 'different diet compositions'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`WROTE`]->(n2)\n        ' {'subj': 'Eaton and Konner', 'obj': 'The Paleolithic Prescription'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`DESCRIBED`]->(n2)\n        ' {'subj': 'book', 'obj': 'diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'diet', 'obj': '65% plant-based'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 0, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`EMPHASIZES`]->(n2)\n        ' {'subj': 'paleo diets', 'obj': 'animal products'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`AVOIDANCE_OF`]->(n2)\n        ' {'subj': 'paleo diets', 'obj': 'processed food'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`AIM_TO`]->(n2)\n        ' {'subj': 'diet advocates', 'obj': '"translate" into modern context'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`FORBIDS`]->(n2)\n        ' {'subj': 'diet', 'obj': 'consumption of all dairy products'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skAyZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x14d5e8fe0>, 'json_data': {'input': ["('Foodstuffs', 'is', 'basis of diet')", "('diet', 'is', 're-imagining of what Paleolithic people ate')", "('proponents', 'recommend', 'different diet compositions')", "('Eaton and Konner', 'wrote', 'The Paleolithic Prescription')", "('book', 'described', 'diet')", "('diet', 'is', '65% plant-based')", "('paleo diets', 'emphasizes', 'animal products')", "('paleo diets', 'avoidance of', 'processed food')", '(\'diet advocates\', \'aim to\', \'"translate" into modern context\')', "('diet', 'forbids', 'consumption of all dairy products')"], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Length', b'82865'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'x-content-type-options', b'nosniff'), (b'x-ratelimit-remaining-requests', b'118'), (b'apim-request-id', b'bb1f5cb2-50c4-41fc-b6f8-ae40efbd8c72'), (b'x-ratelimit-remaining-tokens', b'119786'), (b'x-request-id', b'8f334b88-8bd8-4750-92f4-1fd3a2487e83'), (b'x-ms-client-request-id', b'bb1f5cb2-50c4-41fc-b6f8-ae40efbd8c72'), (b'x-ms-region', b'East US'), (b'azureml-model-session', b'wd3a5f6e70955-5'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Date', b'Thu, 28 Dec 2023 09:03:54 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: == Health effects ==\nThe paleolithic diet is controversial in part because of the exaggerated health claims made for it by its supporters. In general, methodological quality of research into the diet has been poor to moderate.The aspects of the paleolithic diet that result in eating fewer processed foods and less sugar and salt are consistent with mainstream advice about diet. Diets with a paleolithic nutrition pattern have some similarities to traditional ethnic diets such as the Mediterranean diet that have been found to be healthier than the Western diet. Following the paleolithic diet, however, can lead to nutritional deficiencies such as those of vitamin D and calcium, which in turn could lead to compromised bone health; it can also lead to an increased risk of ingesting toxins from high fish consumption.There is some evidence the diet helps achieve weight loss, possibly because of the increased satiety from the foods typically eaten. One trial of obese postmenopausal women found improvements in weight and fat loss after six months, but the benefits had ceased by 24 months; side effects among participants included "weakness, diarrhea, and headaches". As with any other diet regime, the paleolithic diet leads to weight loss because of overall decreased caloric intake, rather than a special feature of the diet itself.There is no good evidence that following a paleolithic diet lessens the risk of cardiovascular disease or metabolic syndrome. There is no evidence the paleolithic diet is effective in treating inflammatory bowel disease.The paleolithic diet similar to the Atkins diet encourages the consumption of large amounts of red meat, especially meats high in saturated fat. This has a negative effect on health in the long run as medical studies have shown that it can lead to increased incidence of cardiovascular disease.\nTriplets:\n'}], 'model': 'gpt-35-turbo-16k', 'stream': False, 'temperature': 0.1}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# ...
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.indices.knowledge_graph.base:> Extracted triplets: [('Smithsonian', 'is', 'National Museum of Natural History'), ('Smithsonian', 'has', 'Human Timeline'), ('Human Timeline', 'is', 'Interactive'), ('Human Timeline', 'belongs to', 'Smithsonian'), ('Smithsonian', 'published by', 'National Museum of Natural History'), ('Smithsonian', 'published in', 'August 2016')]
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Smithsonian', 'obj': 'National Museum of Natural History'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`HAS`]->(n2)\n        ' {'subj': 'Smithsonian', 'obj': 'Human Timeline'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Human Timeline', 'obj': 'Interactive'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`BELONGS_TO`]->(n2)\n        ' {'subj': 'Human Timeline', 'obj': 'Smithsonian'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 13, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PUBLISHED_BY`]->(n2)\n        ' {'subj': 'Smithsonian', 'obj': 'National Museum of Natural History'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 12, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PUBLISHED_IN`]->(n2)\n        ' {'subj': 'Smithsonian', 'obj': 'August 2016'} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 12, 'fields': []}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x14d5e80e0>, 'json_data': {'input': ["('Smithsonian', 'is', 'National Museum of Natural History')", "('Smithsonian', 'has', 'Human Timeline')", "('Human Timeline', 'is', 'Interactive')", "('Human Timeline', 'belongs to', 'Smithsonian')", "('Smithsonian', 'published by', 'National Museum of Natural History')", "('Smithsonian', 'published in', 'August 2016')"], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Length', b'49767'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'x-content-type-options', b'nosniff'), (b'x-ratelimit-remaining-requests', b'116'), (b'apim-request-id', b'76e52a8c-764c-4906-bed3-2c6f480280fb'), (b'x-ratelimit-remaining-tokens', b'119039'), (b'x-request-id', b'ce90fcbe-dae8-475b-b299-c8ad0deddbb3'), (b'x-ms-client-request-id', b'76e52a8c-764c-4906-bed3-2c6f480280fb'), (b'x-ms-region', b'East US'), (b'azureml-model-session', b'wd3a5f6e70955-2'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Date', b'Thu, 28 Dec 2023 09:04:08 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: The Paleolithic diet, Paleo diet, caveman diet,...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == History and terminology ==
# Adrienne Rose Joh...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Foodstuffs ==
# The basis of the diet is a re-...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: Molecular biologist Marion Nestle argues that "...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: Descendants of populations with different diets...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Genetics ==
# The stated rationale for the pal...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: Studies of a variety of populations around the ...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: In 2016, she was quoted as saying "It drives me...
# loaded nodes with 8 nodes
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x14d5e8360>, 'json_data': {'input': ['The Paleolithic diet, Paleo diet, caveman diet, or stone-age diet is a modern fad diet consisting of foods thought by its proponents to mirror those eaten by humans during the Paleolithic era.The diet avoids food processing and typically includes vegetables, fruits, nuts, roots, and meat and excludes dairy products, grains, sugar, legumes, processed oils, salt, alcohol, and coffee. Historians can trace the ideas behind the diet to "primitive" diets advocated in 19th century. In the 1970s, Walter L. Voegtlin popularized a meat-centric "Stone Age" diet; in the 21st century the best-selling books of Loren Cordain popularized the Paleo diet. As of 2019 the paleo-diet industry was worth approximately US$500 million.In the 21st century, the sequencing of the human genome and DNA analysis of the remains of early humans have found evidence that humans evolved rapidly in response to changing diet. This evidence undermines a core premise of the paleolithic diet – that human digestion has remained essentially unchanged over time. Anthropological science has found that human diets in paleolithic times were more varied and less meat-centric than had previously been assumed. Advocates promote the paleolithic diet as a way of improving health. There is some evidence that following it may lead to improvements in body composition and metabolism compared with the typical Western diet or compared with diets recommended by some European nutritional guidelines. On the other hand, following the diet can lead to nutritional deficiencies such as an inadequate calcium intake, and side effects can include weakness, diarrhea, and headaches.', '== History and terminology == Adrienne Rose Johnson writes that the idea that the primitive diet was superior to current dietary habits dates back to the 1890s with such writers as Emmet Densmore and John Harvey Kellogg. Densmore proclaimed that "bread is the staff of death", while Kellogg supported a diet of starchy and grain-based foods in accord with "the ways and likings of our primitive ancestors". Arnold DeVries advocated an early version of the Paleolithic diet in his 1952 book, Primitive Man and His Food. In 1958, Richard Mackarness authored Eat Fat and Grow Slim, which proposed a low-carbohydrate "Stone Age" diet.In his 1975 book The Stone Age Diet, gastroenterologist Walter L. Voegtlin advocated a meat-based diet, with low proportions of vegetables and starchy foods, based on his declaration that humans were "exclusively flesh-eaters" until 10,000 years ago.In 1985 Stanley Boyd Eaton and Melvin Konner published a controversial article in the New England Journal of Medicine proposing that modern humans were biologically very similar to their primitive ancestors and so "genetically programmed" to consume pre-agricultural foods. Eaton and Konner proposed a "discordance hypothesis" by which the mismatch between modern diet and human biology gave rise to lifestyle diseases, such as obesity and diabetes.The diet started to become popular in the 21st century, where it attracted a largely internet-based following using web sites, forums and social media.This diet\'s ideas were further popularized by Loren Cordain, a health scientist with a Ph.D. in physical education, who trademarked the words "The Paleo Diet" and who wrote a 2002 book of that title.In 2012 the paleolithic diet was described as being one of the "latest trends" in diets, based on the popularity of diet books about it; in 2013 and 2014 the Paleolithic diet was Google\'s most searched weight-loss method.The paleolithic or paleo diet is also sometimes referred to as the caveman or stone-age diet.', '== Foodstuffs == The basis of the diet is a re-imagining of what Paleolithic people ate, and different proponents recommend different diet compositions. Eat ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Length', b'66319'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'x-content-type-options', b'nosniff'), (b'x-ratelimit-remaining-requests', b'115'), (b'apim-request-id', b'a5c76b36-5c4c-4cca-9045-f070d3e00de5'), (b'x-ratelimit-remaining-tokens', b'114485'), (b'x-request-id', b'7e43ce74-607f-4d1e-b635-f5743d6939a4'), (b'x-ms-client-request-id', b'a5c76b36-5c4c-4cca-9045-f070d3e00de5'), (b'x-ms-region', b'East US'), (b'azureml-model-session', b'wd3a5f6e70955-8'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Date', b'Thu, 28 Dec 2023 09:04:08 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "200 OK"

# %% [markdown]
# ## Run Pack

# %%
from IPython.display import Markdown

response = neo4j_pack.run("Tell me about the benefits of paleo diet.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': "A question is provided below. Given the question, extract up to 10 keywords from the text. Focus on extracting the keywords that we can use to best lookup answers to the question. Avoid stopwords.\n---------------------\nTell me about the benefits of paleo diet.\n---------------------\nProvide keywords in the following comma-separated format: 'KEYWORDS: <keywords>'\n"}], 'model': 'gpt-35-turbo-16k', 'stream': False, 'temperature': 0.1}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'786'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'5c618aac-df72-4877-97ba-b61b14bb36aa'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'118'), (b'x-ratelimit-remaining-tokens', b'119904'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'ce276dc7-afb2-4fe4-8cf2-de067e80e8f5'), (b'x-ms-client-request-id', b'5c618aac-df72-4877-97ba-b61b14bb36aa'), (b'azureml-model-session', b'turbo-0613-f3706795'), (b'Date', b'Thu, 28 Dec 2023 09:04:11 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['diet']} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: RECORD * 1
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {'diet': [['IS', 're-imagining of what Paleolithic people ate'], ['IS', '65% plant-based'], ['FORBIDS', 'consumption of all dairy products'], ['CAUSED_BY', 'changes in diet'], ['HAS_ALWAYS_BEEN', 'varied']]}
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['benefits']} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 1, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['paleo']} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 16, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#D907]  _: <POOL> picked existing connection bolt-77
# DEBUG:neo4j:[#D907]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#D907]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#D907]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['paleo diet']} {'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#D907]  S: SUCCESS {'t_first': 1, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#D907]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#D907]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#D907]  _: <POOL> released bolt-77
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.SYSTEM: 'system'>, 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': <MessageRole.USER: 'user'>, 'content': "Context information from multiple sources is below.\n---------------------\nkg_schema: {'schema': 'Node properties are the following:\\nEntity {id: STRING},Product {unitPrice: FLOAT, productName: STRING, productID: STRING, unitsOnOrder: INTEGER, supplierID: STRING, categoryID: STRING, discontinued: BOOLEAN, unitsInStock: INTEGER, quantityPerUnit: STRING, reorderLevel: INTEGER},Category {picture: STRING, categoryID: STRING, categoryName: STRING, description: STRING},Supplier {address: STRING, companyName: STRING, region: STRING, contactName: STRING, fax: STRING, phone: STRING, postalCode: STRING, contactTitle: STRING, country: STRING, supplierID: STRING, city: STRING, homePage: STRING},Customer {address: STRING, companyName: STRING, fax: STRING, region: STRING, customerID: STRING, country: STRING, contactName: STRING, contactTitle: STRING, postalCode: STRING, city: STRING, phone: STRING},Order {requiredDate: STRING, shippedDate: STRING, shipName: STRING, shipPostalCode: STRING, shipCity: STRING, shipCountry: STRING, shipAddress: STRING, employeeID: STRING, orderDate: STRING, customerID: STRING, shipVia: STRING, orderID: STRING, shipRegion: STRING, freight: STRING}\\nRelationship properties are the following:\\nORDERS {unitPrice: STRING, orderID: STRING, quantity: INTEGER, discount: STRING, productID: STRING}\\nThe relationships are the following:\\n(:Entity)-[:IS]->(:Entity),(:Entity)-[:POPULARIZED]->(:Entity),(:Entity)-[:DESCRIBED_AS]->(:Entity),(:Entity)-[:WORTH]->(:Entity),(:Entity)-[:REMAINED_ESSENTIALLY_UNCHANGED]->(:Entity),(:Entity)-[:HUMAN_DIETS]->(:Entity),(:Entity)-[:CAUSED_BY]->(:Entity),(:Entity)-[:FORBIDS]->(:Entity),(:Entity)-[:RECOMMEND]->(:Entity),(:Entity)-[:WROTE]->(:Entity),(:Entity)-[:DESCRIBED]->(:Entity),(:Entity)-[:AVOIDANCE_OF]->(:Entity),(:Entity)-[:EMPHASIZES]->(:Entity),(:Entity)-[:AIM_TO]->(:Entity),(:Entity)-[:LEADS_TO]->(:Entity),(:Entity)-[:UNDERMINES]->(:Entity),(:Entity)-[:LEAD_TO]->(:Entity),(:Entity)-[:HELPS_ACHIEVE]->(:Entity),(:Entity)-[:PROMOTES]->(:Entity),(:Entity)-[:IS_CONTROVERSIAL_IN_PART_BECAUSE_OF]->(:Entity),(:Entity)-[:IS_CONTROVERSIAL_IN]->(:Entity),(:Entity)-[:HAS_BEEN_POOR_TO_MODERATE]->(:Entity),(:Entity)-[:RESULT_IN]->(:Entity),(:Entity)-[:CONSISTENT_WITH]->(:Entity),(:Entity)-[:HAVE_SIMILARITIES_TO]->(:Entity),(:Entity)-[:HAVE_BEEN_FOUND_TO_BE_HEALTHIER_THAN]->(:Entity),(:Entity)-[:CAN_LEAD_TO]->(:Entity),(:Entity)-[:RARELY_INCLUDED]->(:Entity),(:Entity)-[:WOULD_HAVE_BEEN]->(:Entity),(:Entity)-[:DID_NOT_SUFFER_FROM]->(:Entity),(:Entity)-[:MANY_CHRONIC_DISEASES_AND_DEGENERATIVE_CONDITIONS_EVIDENT_IN_MODERN_WESTERN_POPULATIONS_HAVE_ARISEN_BECAUSE_OF]->(:Entity),(:Entity)-[:MANY_CHRONIC_DISEASES_AND_DEGENERATIVE_CONDITIONS]->(:Entity),(:Entity)-[:MANY_CHRONIC_DISEASES_AND_DEGENERATIVE_CONDITIONS_EVIDENT_IN]->(:Entity),(:Entity)-[:FORMED_THEIR_DIETARY_RECOMMENDATIONS_BASED_ON]->(:Entity),(:Entity)-[:FORMED_THEIR_DIETARY_RECOMMENDATIONS]->(:Entity),(:Entity)-[:CAN_LIVE_HEALTHILY_WITH]->(:Entity),(:Entity)-[:CAN_LIVE_HEALTHILY]->(:Entity),(:Entity)-[:HAS]->(:Entity),(:Entity)-[:PUBLISHED_IN]->(:Entity),(:Entity)-[:PUBLISHED_BY]->(:Entity),(:Entity)-[:BELONGS_TO]->(:Entity),(:Entity)-[:HAVE_NOT_BEEN_ABLE_TO_ADAPT_TO]->(:Entity),(:Entity)-[:ARGUE]->(:Entity),(:Entity)-[:ARGUE_THAT]->(:Entity),(:Entity)-[:CONFERS_LACTOSE_TOLERANCE_INTO]->(:Entity),(:Product)-[:PART_OF]->(:C ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'1041'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'd40ecf5e-a05b-4946-ac4e-3c39b01da3aa'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'117'), (b'x-ratelimit-remaining-tokens', b'119888'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'0cefcc4f-ba6e-4809-8d67-97bf46037e5a'), (b'x-ms-client-request-id', b'd40ecf5e-a05b-4946-ac4e-3c39b01da3aa'), (b'azureml-model-session', b'turbo-0613-65c7dc11'), (b'Date', b'Thu, 28 Dec 2023 09:04:12 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# <b>The benefits of the paleo diet include a re-imagining of what Paleolithic people ate, a diet that is 65% plant-based, and the forbidding of consumption of all dairy products. Additionally, the paleo diet has always been varied, which can contribute to its overall health benefits.</b>

# %% [markdown]
# 我们尝试使用KG混合查询引擎。请参见下面的代码。你可以通过替换 `Neo4jQueryEngineType` 枚举中的其他查询引擎类型来以类似的方式尝试任何其他查询引擎。

# %%
neo4j_pack = Neo4jQueryEnginePack(
  username = username,
  password = password,
  url = url,
  database = database,
  docs = documents,
  query_engine_type = Neo4jQueryEngineType.KG_HYBRID
)

response = neo4j_pack.run("Tell me about the benefits of paleo diet.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# DEBUG:neo4j:[#0000]  _: <POOL> created, direct address IPv4Address(('127.0.0.1', 7687))
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='READ', database=None
# DEBUG:neo4j:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j:[#0000]  _: <RESOLVE> in: 127.0.0.1:7687
# DEBUG:neo4j:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j:[#DA8F]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j:[#DA8F]  C: <HANDSHAKE> 0x00040405 0x00020404 0x00000104 0x00000003
# DEBUG:neo4j:[#DA8F]  S: <HANDSHAKE> 0x00000405
# DEBUG:neo4j:[#DA8F]  C: HELLO {'user_agent': 'neo4j-python/5.15.0 Python/3.11.6-final-0 (darwin)', 'bolt_agent': {'product': 'neo4j-python/5.15.0', 'platform': 'Darwin 23.2.0; arm64', 'language': 'Python/3.11.6-final-0', 'language_details': 'CPython; 3.11.6-final-0 (main, Oct  3 2023 10:37:07) [Clang 15.0.7 ]'}}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j:[#DA8F]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'server': 'Neo4j/5.15.0', 'connection_id': 'bolt-78', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "node"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {labels: nodeLabels, properties: properties} AS output\n\n' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> client state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': ['output']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 23, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "relationship"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {type: nodeLabels, properties: properties} AS output\n' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': ['output']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 5, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE type = "RELATIONSHIP" AND elementType = "node"\nUNWIND other AS other_node\nRETURN {start: label, type: property, end: toString(other_node)} AS output\n' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 0, 'fields': ['output']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'r', 't_last': 7, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                ' {} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 's', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: The Paleolithic diet, Paleo diet, caveman diet,...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Foodstuffs ==
# The basis of the diet is a re-...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Health effects ==
# The paleolithic diet is co...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == Genetics ==
# The stated rationale for the pal...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: == See also ==
#
#
# == Citations ==
#
#
# == Reference...
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The Paleolithic diet, Paleo diet, caveman diet, or stone-age diet is a modern fad diet consisting of foods thought by its proponents to mirror those eaten by humans during the Paleolithic era.The diet avoids food processing and typically includes vegetables, fruits, nuts, roots, and meat and excludes dairy products, grains, sugar, legumes, processed oils, salt, alcohol, and coffee. Historians can trace the ideas behind the diet to "primitive" diets advocated in 19th century. In the 1970s, Walter L. Voegtlin popularized a meat-centric "Stone Age" diet; in the 21st century the best-selling books of Loren Cordain popularized the Paleo diet. As of 2019 the paleo-diet industry was worth approximately US$500 million.In the 21st century, the sequencing of the human genome and DNA analysis of the remains of early humans have found evidence that humans evolved rapidly in response to changing diet. This evidence undermines a core premise of the paleolithic diet – that human digestion has remained essentially unchanged over time. Anthropological science has found that human diets in paleolithic times were more varied and less meat-centric than had previously been assumed.\nAdvocates promote the paleolithic diet as a way of improving health. There is some evidence that following it may lead to improvements in body composition and metabolism compared with the typical Western diet or compared with diets recommended by some European nutritional guidelines. On the other hand, following the diet can lead to nutritional deficiencies such as an inadequate calcium intake, and side effects can include weakness, diarrhea, and headaches.\n\n\n== History and terminology ==\nAdrienne Rose Johnson writes that the idea that the primitive diet was superior to current dietary habits dates back to the 1890s with such writers as Emmet Densmore and John Harvey Kellogg. Densmore proclaimed that "bread is the staff of death", while Kellogg supported a diet of starchy and grain-based foods in accord with "the ways and likings of our primitive ancestors". Arnold DeVries advocated an early version of the Paleolithic diet in his 1952 book, Primitive Man and His Food. In 1958, Richard Mackarness authored Eat Fat and Grow Slim, which proposed a low-carbohydrate "Stone Age" diet.In his 1975 book The Stone Age Diet, gastroenterologist Walter L. Voegtlin advocated a meat-based diet, with low proportions of vegetables and starchy foods, based on his declaration that humans were "exclusively flesh-eaters" until 10,000 years ago.In 1985 Stanley Boyd Eaton and Melvin Konner published a controversial article in the New England Journal of Medicine proposing that modern humans were biologically very similar to their primitive ancestors and so "genetically programmed" to consume pre-agricultural foods. Eaton and Konner proposed a "discordance hypothesis" by which the mismatch between modern diet and human biology gave rise to lifestyle diseases, such as obesity and diabetes.The diet started to become popular in the 21st century, where it attracted a largely internet-based following using web sites, forums and social media.This diet\'s ideas were further popularized by Loren Cordain, a health scientist with a Ph.D. in physical education, who trademarked the words "The Paleo Diet" and who wrote a 2002 book of that title.In 2012 the paleolithic diet was de ...
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7890 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14d10e310>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'Connection established', [])
# DEBUG:httpcore.proxy:start_tls.started ssl_context=<ssl.SSLContext object at 0x14d1f6f90> server_hostname='firstaiproject.openai.azure.com' timeout=60.0
# DEBUG:httpcore.proxy:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14be21050>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'1155'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'be7cc7b8-aa45-4e58-a793-39c5f87667b9'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'116'), (b'x-ratelimit-remaining-tokens', b'119872'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'cff7eaad-1d6f-4434-ab4e-c8ecd14144c2'), (b'x-ms-client-request-id', b'be7cc7b8-aa45-4e58-a793-39c5f87667b9'), (b'azureml-model-session', b'turbo-0613-f3706795'), (b'Date', b'Thu, 28 Dec 2023 09:04:15 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.indices.knowledge_graph.base:> Extracted triplets: [('Paleolithic diet', 'is', 'fad diet'), ('Paleolithic diet', 'consists of', 'vegetables'), ('Paleolithic diet', 'consists of', 'fruits'), ('Paleolithic diet', 'consists of', 'nuts'), ('Paleolithic diet', 'consists of', 'roots'), ('Paleolithic diet', 'consists of', 'meat'), ('Paleolithic diet', 'excludes', 'dairy products'), ('Paleolithic diet', 'excludes', 'grains'), ('Paleolithic diet', 'excludes', 'sugar'), ('Paleolithic diet', 'excludes', 'legumes')]
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'fad diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 2, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA5ZA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`CONSISTS_OF`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'vegetables'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 19, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA55A=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`CONSISTS_OF`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'fruits'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA6JA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`CONSISTS_OF`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'nuts'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA6ZA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`CONSISTS_OF`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'roots'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA6pA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`CONSISTS_OF`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'meat'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA65A=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`EXCLUDES`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'dairy products'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 14, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA7ZA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`EXCLUDES`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'grains'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 14, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA7pA=', 'stats': {'contains-updates': True, 'relationships-created': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`EXCLUDES`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'sugar'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA75A=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`EXCLUDES`]->(n2)\n        ' {'subj': 'Paleolithic diet', 'obj': 'legumes'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 0, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/minp/miniconda3/envs/llamaindex_nebulagraph_phillies/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x14f20d120>, 'json_data': {'input': ["('Paleolithic diet', 'is', 'fad diet')", "('Paleolithic diet', 'consists of', 'vegetables')", "('Paleolithic diet', 'consists of', 'fruits')", "('Paleolithic diet', 'consists of', 'nuts')", "('Paleolithic diet', 'consists of', 'roots')", "('Paleolithic diet', 'consists of', 'meat')", "('Paleolithic diet', 'excludes', 'dairy products')", "('Paleolithic diet', 'excludes', 'grains')", "('Paleolithic diet', 'excludes', 'sugar')", "('Paleolithic diet', 'excludes', 'legumes')"], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7890 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14ed01150>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'CONNECT']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'Connection established', [])
# DEBUG:httpcore.proxy:start_tls.started ssl_context=<ssl.SSLContext object at 0x14d1f7530> server_hostname='firstaiproject.openai.azure.com' timeout=5.0
# DEBUG:httpcore.proxy:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x14d4c8d90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Length', b'82865'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'x-content-type-options', b'nosniff'), (b'x-ratelimit-remaining-requests', b'117'), (b'apim-request-id', b'19f11c7b-7848-4c0e-9f56-ecb527956a88'), (b'x-ratelimit-remaining-tokens', b'114371'), (b'x-request-id', b'40e290fa-f645-4bd1-8ea6-3015b99ff9ed'), (b'x-ms-client-request-id', b'19f11c7b-7848-4c0e-9f56-ecb527956a88'), (b'x-ms-region', b'East US'), (b'azureml-model-session', b'wd3a5f6e70955-2'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Date', b'Thu, 28 Dec 2023 09:04:16 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: == Foodstuffs ==\nThe basis of the diet is a re-imagining of what Paleolithic people ate, and different proponents recommend different diet compositions. Eaton and Konner, for example, wrote a 1988 book The Paleolithic Prescription with Marjorie Shostak, and it described a diet that is 65% plant-based. This is not typical of more recently devised paleo diets; Loren Cordain\'s – probably the most popular – instead emphasizes animal products and avoidance of processed food. Diet advocates concede the modern paleolithic diet cannot be a faithful recreation of what paleolithic people ate, and instead aim to "translate" that into a modern context, avoiding such likely historical practices as cannibalism.Foodstuffs that have been described as permissible include:\n\n"vegetables, fruits, nuts, roots, meat, and organ meats";\n"vegetables (including root vegetables), fruit (including fruit oils, e.g., olive oil, coconut oil, and palm oil), nuts, fish, meat, and eggs, and it excluded dairy, grain-based foods, legumes, extra sugar, and nutritional products of industry (including refined fats and refined carbohydrates)"; and\n"avoids processed foods, and emphasizes eating vegetables, fruits, nuts and seeds, eggs, and lean meats".The diet forbids the consumption of all dairy products. This is because milking did not exist until animals were domesticated after the Paleolithic era.\n\n\n=== Ancestral diet ===\n\nAdopting the Paleolithic diet assumes that modern humans can reproduce the hunter-gatherer diet. Molecular biologist Marion Nestle argues that "knowledge of the relative proportions of animal and plant foods in the diets of early humans is circumstantial, incomplete, and debatable and that there are insufficient data to identify the composition of a genetically determined optimal diet. The evidence related to Paleolithic diets is best interpreted as supporting the idea that diets based largely on plant foods promote health and longevity, at least under conditions of food abundance and physical activity." Ideas about Paleolithic diet and nutrition are at best hypothetical.The data for Cordain\'s book only came from six contemporary hunter-gatherer groups, mainly living in marginal habitats. One of the studies was on the !Kung, whose diet was recorded for a single month, and one was on the Inuit. Due to these limitations, the book has been criticized as painting an incomplete picture of the diets of Paleolithic humans. It has been noted that the rationale for the diet does not adequately account for the fact that, due to the pressures of artificial selection, most modern domesticated plants and animals differ drastically from their Paleolithic ancestors; likewise, their nutritional profiles are very different from their ancient counterparts. For example, wild almonds produce potentially fatal levels of cyanide, but this trait has been bred out of domesticated varieties using artificial selection. Many vegetables, such as broccoli, did not exist in the Paleolithic period; broccoli, cabbage, cauliflower, and kale are modern cultivars of the ancient species Brassica oleracea.Trying to devise an ideal diet by studying contemporary hunter-gatherers is difficult because of the great disparities that exist; for example, the animal-derived calorie percentage ranges from 25% for the Gwi people of southern Africa to 99% f ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'1216'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'87ba9808-5c19-4977-b581-fa77eeefdaa6'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'116'), (b'x-ratelimit-remaining-tokens', b'119856'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'1e42c669-a87c-43b2-80d6-f12e072a6757'), (b'x-ms-client-request-id', b'87ba9808-5c19-4977-b581-fa77eeefdaa6'), (b'azureml-model-session', b'turbo-0613-b28806f7'), (b'Date', b'Thu, 28 Dec 2023 09:04:18 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.indices.knowledge_graph.base:> Extracted triplets: [('Foodstuffs', 'is', 'basis of diet'), ('diet', 'is', 're-imagining of what Paleolithic people ate'), ('proponents', 'recommend', 'different diet compositions'), ('Eaton and Konner', 'wrote', 'The Paleolithic Prescription'), ('book', 'described', 'diet'), ('diet', 'is', '65% plant-based'), ('paleo diets', 'emphasizes', 'animal products'), ('paleo diets', 'avoidance of', 'processed food'), ('diet advocates', 'aim to', '"translate" into modern context'), ('diet', 'forbids', 'consumption of all dairy products')]
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Foodstuffs', 'obj': 'basis of diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 31, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'diet', 'obj': 're-imagining of what Paleolithic people ate'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`RECOMMEND`]->(n2)\n        ' {'subj': 'proponents', 'obj': 'different diet compositions'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 17, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`WROTE`]->(n2)\n        ' {'subj': 'Eaton and Konner', 'obj': 'The Paleolithic Prescription'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 16, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`DESCRIBED`]->(n2)\n        ' {'subj': 'book', 'obj': 'diet'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 15, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'diet', 'obj': '65% plant-based'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 0, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`EMPHASIZES`]->(n2)\n        ' {'subj': 'paleo diets', 'obj': 'animal products'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 16, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`AVOIDANCE_OF`]->(n2)\n        ' {'subj': 'paleo diets', 'obj': 'processed food'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 14, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`AIM_TO`]->(n2)\n        ' {'subj': 'diet advocates', 'obj': '"translate" into modern context'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 12, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`FORBIDS`]->(n2)\n        ' {'subj': 'diet', 'obj': 'consumption of all dairy products'} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 10, 'fields': []}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA8JA=', 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# ...
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'786'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'035f3598-f3b1-4e83-9f4d-0a202cbd2565'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'116'), (b'x-ratelimit-remaining-tokens', b'119792'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'a909cc69-3949-4cca-996f-52573ef808fb'), (b'x-ms-client-request-id', b'035f3598-f3b1-4e83-9f4d-0a202cbd2565'), (b'azureml-model-session', b'turbo-0613-bc549a28'), (b'Date', b'Thu, 28 Dec 2023 09:04:28 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['diet']} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 1, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: RECORD * 1
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA9JA=', 'type': 'r', 't_last': 1, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {'diet': [['IS', 're-imagining of what Paleolithic people ate'], ['IS', '65% plant-based'], ['FORBIDS', 'consumption of all dairy products'], ['CAUSED_BY', 'changes in diet'], ['HAS_ALWAYS_BEEN', 'varied']]}
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['benefits']} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 0, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA9JA=', 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['paleo']} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 0, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA9JA=', 'type': 'r', 't_last': 1, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database='neo4j'
# DEBUG:neo4j:[#DA8F]  _: <POOL> picked existing connection bolt-78
# DEBUG:neo4j:[#DA8F]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j:[#DA8F]  _: <POOL> handing out existing connection
# DEBUG:neo4j:[#DA8F]  C: RUN 'MATCH p=(n1:Entity)-[*1..2]->() WHERE n1.id IN $subjs UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30' {'subjs': ['paleo diet']} {'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  C: PULL {'n': 1000}
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'t_first': 0, 'fields': ['subj', 'flattened_rels']}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j:[#DA8F]  S: SUCCESS {'bookmark': 'FB:kcwQMyFOofwtTyGEbSgUat+G3skA9JA=', 'type': 'r', 't_last': 1, 'db': 'neo4j'}
# DEBUG:neo4j:[#DA8F]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j:[#DA8F]  _: <POOL> released bolt-78
# DEBUG:llama_index.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x14f20e3e0>, 'json_data': {'input': ['Tell me about the benefits of paleo diet.'], 'model': <OpenAIEmbeddingModeModel.TEXT_EMBED_ADA_002: 'text-embedding-ada-002'>, 'encoding_format': 'base64'}, 'headers': {'api-key': '5f98852154cf442fbefbb5f8be916294'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Length', b'8397'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'x-content-type-options', b'nosniff'), (b'x-ratelimit-remaining-requests', b'115'), (b'apim-request-id', b'83644b62-5d9b-443d-a262-065095373344'), (b'x-ratelimit-remaining-tokens', b'109330'), (b'x-request-id', b'e663ac46-94ba-4846-ae75-aa3c02170f7f'), (b'x-ms-client-request-id', b'83644b62-5d9b-443d-a262-065095373344'), (b'x-ms-region', b'East US'), (b'azureml-model-session', b'wd3a5f6e70955-8'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Date', b'Thu, 28 Dec 2023 09:04:28 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-07-01-preview "200 OK"
# DEBUG:llama_index.indices.knowledge_graph.retrievers:Found the following rel_texts+query similarites: [0.8638272561459364, 0.863292342026343, 0.8603669323542859]
# DEBUG:llama_index.indices.knowledge_graph.retrievers:Found the following top_k rel_texts: ["['IS', 're-imagining of what Paleolithic people ate']", "['IS', '65% plant-based']", "['FORBIDS', 'consumption of all dairy products']", "['CAUSED_BY', 'changes in diet']", "['HAS_ALWAYS_BEEN', 'varied']"]
# INFO:llama_index.indices.knowledge_graph.retrievers:> Querying with idx: 16f36b9c-6544-4250-b079-d39dd968b8a2: == Genetics ==
# The stated rationale for the paleolithic diet is that human ge...
# INFO:llama_index.indices.knowledge_graph.retrievers:> Querying with idx: 12bfcd97-3d7c-4513-a015-afa741a1ff08: == Foodstuffs ==
# The basis of the diet is a re-imagining of what Paleolithic ...
# INFO:llama_index.indices.knowledge_graph.retrievers:> Querying with idx: 5e7a0ec4-cb8b-4075-96bb-1200662a50d2: == Health effects ==
# The paleolithic diet is controversial in part because of...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-35-turbo-16k/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.SYSTEM: 'system'>, 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': <MessageRole.USER: 'user'>, 'content': 'Context information from multiple sources is below.\n---------------------\n== Genetics ==\nThe stated rationale for the paleolithic diet is that human genes of modern times are unchanged from those of 10,000 years ago, and that the diet of that time is therefore the best fit with humans today. Loren Cordain has described the paleo diet as "the one and only diet that ideally fits our genetic makeup".The argument is that modern humans have not been able to adapt to the new circumstances. According to Cordain, before the agricultural revolution, hunter-gatherer diets rarely included grains, and obtaining milk from wild animals would have been "nearly impossible". Advocates of the diet argue that the increase in diseases of affluence after the dawn of agriculture was caused by these changes in diet, but others have countered that it may be that pre-agricultural hunter-gatherers did not suffer from the diseases of affluence because they did not live long enough to develop them.According to the model from the evolutionary discordance hypothesis, "many chronic diseases and degenerative conditions evident in modern Western populations have arisen because of a mismatch between Stone Age genes and modern lifestyles." Advocates of the modern paleo diet have formed their dietary recommendations based on this hypothesis. They argue that modern humans should follow a diet that is nutritionally closer to that of their Paleolithic ancestors.\nThe evolutionary discordance is incomplete, since it is based mainly on the genetic understanding of the human diet and a unique model of human ancestral diets, without taking into account the flexibility and variability of the human dietary behaviors over time. Studies of a variety of populations around the world show that humans can live healthily with a wide variety of diets and that humans have evolved to be flexible eaters. Lactase persistence, which confers lactose tolerance into adulthood, is an example of how some humans have adapted to the introduction of dairy into their diet. While the introduction of grains, dairy, and legumes during the Neolithic revolution may have had some adverse effects on modern humans, if humans had not been nutritionally adaptable, these technological developments would have been dropped.Since the publication of Eaton and Konner\'s paper in 1985, analysis of the DNA of primitive human remains has provided evidence that evolving humans were continually adapting to new diets, thus challenging the hypothesis underlying the paleothic diet. Evolutionary biologist Marlene Zuk writes that the idea that our genetic makeup today matches that of our ancestors is misconceived, and that in debate Cordain was "taken aback" when told that 10,000 years was "plenty of time" for an evolutionary change in human digestive abilities to have taken place. On this basis Zuk dismisses Cordain\'s claim that the paleo diet is "the one and only diet that fits our genetic makeup".Paleoanthropologist Peter Ungar has written that the paleo diet is a "myth", on account both of its invocation of a single suitable diet when in reality humans have always been a "work in progress", and because diet has always been varied because humans were spread widely over the planet.Anthropological geneticist Anne C. Stone has said that humans have adapted in the last 10,000 years in response to radical ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Cache-Control', b'no-cache, must-revalidate'), (b'Content-Length', b'1681'), (b'Content-Type', b'application/json'), (b'access-control-allow-origin', b'*'), (b'apim-request-id', b'5eefbc67-72c7-4006-86cd-3347764a7213'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-region', b'East US'), (b'x-ratelimit-remaining-requests', b'116'), (b'x-ratelimit-remaining-tokens', b'119776'), (b'x-accel-buffering', b'no'), (b'x-request-id', b'd03bf95c-1c7b-4edd-b783-cd5d83dfba38'), (b'x-ms-client-request-id', b'5eefbc67-72c7-4006-86cd-3347764a7213'), (b'azureml-model-session', b'turbo-0613-ea3060f9'), (b'Date', b'Thu, 28 Dec 2023 09:04:31 GMT')])
# INFO:httpx:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://firstaiproject.openai.azure.com//openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2023-07-01-preview "200 OK"
# <b>The paleo diet is believed to have several benefits. Advocates of the diet argue that it is nutritionally closer to the diet of our Paleolithic ancestors, which they believe is the best fit for our genetic makeup. They claim that following a paleo diet can help prevent or reduce the risk of chronic diseases and degenerative conditions that are common in modern Western populations. The diet emphasizes the consumption of whole, unprocessed foods such as vegetables, fruits, nuts, seeds, lean meats, and fish, while avoiding processed foods, grains, legumes, and dairy products. Some studies suggest that the paleo diet may help with weight loss, as it promotes the consumption of satiating foods and reduces overall caloric intake. However, it is important to note that the health benefits of the paleo diet are still a topic of debate, and more research is needed to fully understand its long-term effects on health.</b>

# %% [markdown]
# ## 知识图谱查询策略比较
#
# 下表列出了7种查询引擎的详细信息，以及基于与NebulaGraph和LlamaIndex的实验得出的它们的优缺点，这在博客文章 [利用 LlamaIndex 浏览知识图谱的 7 种查询策略](https://www.toutiao.com/article/7317169514767008271/).

# %% [markdown]
# ![知识图谱查询策略比较](https://p3-sign.toutiaoimg.com/tos-cn-i-6w9my0ksvp/ffa837ee967d46f9baaf28784b7ec0c0~noop.image?_iz=58558&from=article.pc_detail&lk3s=953192f4&x-expires=1704356130&x-signature=GXA885tOjv39mCKu1oftcWCcWtA%3D)
